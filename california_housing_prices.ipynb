# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanu-4290/Ai-and-ML/blob/main/california_housing_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mimport pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data  = pd.read_csv('/content/housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'],axis =1)
y = data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train, x_test , y_train , y_test =  train_test_split(x,y , test_size=0.2)

# %%
train_data = x_train.join(y_train )
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17030    -122.25     37.51                45.0        989.0           174.0
# 13258    -117.69     34.10                17.0       3759.0          1035.0
# 6286     -117.93     34.04                30.0       1336.0           239.0
# 2650     -124.09     40.44                38.0       2220.0           426.0
# 10987    -117.81     33.75                23.0       3498.0           636.0
# ...          ...       ...                 ...          ...             ...
# 6957     -118.06     33.98                38.0       1862.0           319.0
# 4060     -118.45     34.16                22.0       7828.0          2038.0
# 2448     -119.53     36.55                34.0       2065.0           343.0
# 15993    -122.47     37.76                34.0       2807.0           487.0
# 9700     -121.62     36.67                31.0       2697.0           690.0
#
#        population  households  median_income ocean_proximity  \
# 17030       504.0       180.0         4.8382      NEAR OCEAN
# 13258      1722.0       847.0         2.6074          INLAND
# 6286        905.0       253.0         4.8854       <1H OCEAN
# 2650       1041.0       401.0         2.3947       <1H OCEAN
# 10987      1574.0       642.0         5.0210       <1H OCEAN
# ...           ...         ...            ...             ...
# 6957        975.0       305.0         4.7266       <1H OCEAN
# 4060       3303.0      1922.0         3.6171       <1H OCEAN
# 2448       1041.0       313.0         3.2917          INLAND
# 15993      1152.0       445.0         5.1893        NEAR BAY
# 9700       2220.0       665.0         2.5329       <1H OCEAN
#
#        median_house_value
# 17030            289400.0
# 13258            137500.0
# 6286             178100.0
# 2650              70500.0
# 10987            252200.0
# ...                   ...
# 6957             177600.0
# 4060             318300.0
# 2448             111500.0
# 15993            420300.0
# 9700             135200.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.hist( figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#pre proccessing
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms '] = np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>],
#        [<Axes: title={'center': 'total_bedrooms '}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
#truning ocean values to 0 &1
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7253
# INLAND        5172
# NEAR OCEAN    2117
# NEAR BAY      1800
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis =1)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17030    -122.25     37.51                45.0     6.897705           174.0
# 13258    -117.69     34.10                17.0     8.232174          1035.0
# 6286     -117.93     34.04                30.0     7.198184           239.0
# 2650     -124.09     40.44                38.0     7.705713           426.0
# 10987    -117.81     33.75                23.0     8.160232           636.0
# ...          ...       ...                 ...          ...             ...
# 6957     -118.06     33.98                38.0     7.529943           319.0
# 4060     -118.45     34.16                22.0     8.965590          2038.0
# 2448     -119.53     36.55                34.0     7.633370           343.0
# 15993    -122.47     37.76                34.0     7.940228           487.0
# 9700     -121.62     36.67                31.0     7.900266           690.0
#
#        population  households  median_income  median_house_value  \
# 17030    6.224558    5.198497         4.8382            289400.0
# 13258    7.451822    6.742881         2.6074            137500.0
# 6286     6.809039    5.537334         4.8854            178100.0
# 2650     6.948897    5.996452         2.3947             70500.0
# 10987    7.362011    6.466145         5.0210            252200.0
# ...           ...         ...            ...                 ...
# 6957     6.883463    5.723585         4.7266            177600.0
# 4060     8.102889    7.561642         3.6171            318300.0
# 2448     6.948897    5.749393         3.2917            111500.0
# 15993    7.050123    6.100319         5.1893            420300.0
# 9700     7.705713    6.501290         2.5329            135200.0
#
#        total_bedrooms   <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 17030         5.164786      False   False   False     False        True
# 13258         6.943122      False    True   False     False       False
# 6286          5.480639       True   False   False     False       False
# 2650          6.056784       True   False   False     False       False
# 10987         6.456770       True   False   False     False       False
# ...                ...        ...     ...     ...       ...         ...
# 6957          5.768321       True   False   False     False       False
# 4060          7.620215       True   False   False     False       False
# 2448          5.840642      False    True   False     False       False
# 15993         6.190315      False   False   False      True       False
# 9700          6.538140       True   False   False     False       False
#
# [16346 rows x 15 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='longitude', y='latitude', data= train_data,  hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
x_train,y_train  = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms '] = np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households']+1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis =1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18357    -122.10     37.36                32.0     7.268223           199.0
# 12049    -117.56     33.88                36.0     6.732211           210.0
# 8322     -118.30     33.95                41.0     7.629490           550.0
# 5601     -118.28     33.80                38.0     7.294377           329.0
# 1384     -122.11     37.99                16.0     8.272315           710.0
# ...          ...       ...                 ...          ...             ...
# 4894     -118.24     34.02                48.0     6.297109           150.0
# 3852     -118.44     34.17                25.0     8.510571          1134.0
# 1706     -122.32     37.95                37.0     7.543273           353.0
# 5425     -118.42     34.02                34.0     7.716015           444.0
# 19266    -122.72     38.44                52.0     5.241747            62.0
#
#        population  households  median_income  median_house_value  \
# 18357    6.212606    5.308268         9.3586            500001.0
# 12049    6.583409    5.198497         2.4861             96200.0
# 8322     7.498870    6.228511         1.2455            100800.0
# 5601     7.096721    5.817111         4.0000            165500.0
# 1384     7.486053    6.517671         5.1297            206700.0
# ...           ...         ...            ...                 ...
# 4894     6.349139    4.744932         1.8485             90600.0
# 3852     7.571474    6.865891         3.8081            286700.0
# 1706     6.797940    5.886104         4.4500            196600.0
# 5425     6.881411    6.025866         4.9676            414100.0
# 19266    5.710427    4.290459         0.9437            129200.0
#
#        total_bedrooms   <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN  \
# 18357         5.298317      False   False   False      True       False
# 12049         5.351858      False    True   False     False       False
# 8322          6.311735       True   False   False     False       False
# 5601          5.799093       True   False   False     False       False
# 1384          6.566672      False   False   False      True       False
# ...                ...        ...     ...     ...       ...         ...
# 4894          5.017280       True   False   False     False       False
# 3852          7.034388       True   False   False     False       False
# 1706          5.869297      False   False   False      True       False
# 5425          6.098074       True   False   False     False       False
# 19266         4.143135       True   False   False     False       False
#
#        bedroom_ratio  household_rooms
# 18357      27.379457         1.369227
# 12049      31.193320         1.295030
# 8322       72.088699         1.224930
# 5601       45.103233         1.253952
# 1384       85.828452         1.269213
# ...              ...              ...
# 4894       23.820454         1.327123
# 3852      133.246049         1.239544
# 1706       46.796660         1.281539
# 5425       57.542654         1.280482
# 19266      11.828118         1.221722
#
# [4087 rows x 17 columns]

# %%
reg.score(x_train,y_train)
# Out:
# 0.6719636765579742

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(x_train , y_train )
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-177-2855098603.py in <cell line: 0>()
# ----> 1 forest.score(x_test, y_test )
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     660         from .metrics import r2_score
#     661
# --> 662         y_pred = self.predict(X)
#     663         return r2_score(y, y_pred, sample_weight=sample_weight)
#     664
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in predict(self, X)
#    1064         check_is_fitted(self)
#    1065         # Check data
# -> 1066         X = self._validate_X_predict(X)
#    1067
#    1068         # Assign chunk of trees to jobs
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     636             ensure_all_finite = True
#     637
# --> 638         X = validate_data(
#     639             self,
#     640             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _check_feature_names(estimator, X, reset)
#    2775             message += "Feature names must be in the same order as they were in fit.\n"
#    2776
# -> 2777         raise ValueError(message)
#    2778
#    2779
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - ocean_proximity
# Feature names seen at fit time, yet now missing:
# - <1H OCEAN
# - INLAND
# - ISLAND
# - NEAR BAY
# - NEAR OCEAN
# - ...

# %%
from sklearn.model_selection import GridSearchCV

para_grid = {
    "n_estimators":[3,10,30],
    "max_features":[2,4,6,8]
}
grid_search = GridSearchCV(forest, para_grid, cv=5, scoring='neg_mean_squared_error', return_train_score=True)
grid_search.fit(x_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=8, n_estimators=30)

# %%
best_forest = grid_search.best_estimator_
best_forest.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-184-3967781917.py in <cell line: 0>()
#       1 best_forest = grid_search.best_estimator_
# ----> 2 best_forest.score(x_test, y_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     660         from .metrics import r2_score
#     661
# --> 662         y_pred = self.predict(X)
#     663         return r2_score(y, y_pred, sample_weight=sample_weight)
#     664
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in predict(self, X)
#    1064         check_is_fitted(self)
#    1065         # Check data
# -> 1066         X = self._validate_X_predict(X)
#    1067
#    1068         # Assign chunk of trees to jobs
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     636             ensure_all_finite = True
#     637
# --> 638         X = validate_data(
#     639             self,
#     640             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _check_feature_names(estimator, X, reset)
#    2775             message += "Feature names must be in the same order as they were in fit.\n"
#    2776
# -> 2777         raise ValueError(message)
#    2778
#    2779
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - ocean_proximity
# Feature names seen at fit time, yet now missing:
# - <1H OCEAN
# - INLAND
# - ISLAND
# - NEAR BAY
# - NEAR OCEAN
# - ...

# %%
0.8152620670198727
# Out:
# 0.8152620670198727
